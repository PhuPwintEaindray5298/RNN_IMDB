# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import load_model

# %%
#Load imdb dataset word index
word_index = imdb.get_word_index()
reverse_word_index = {value:key for key,value in word_index.items()}

# %%
model = load_model('simple_rnn_imdb.h5')
model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 500, 130)       │     1,300,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, 130)            │        33,930 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           131 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,334,063 (5.09 MB)
#  Trainable params: 1,334,061 (5.09 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
model.get_weights()
# Out:
# [array([[ 0.30605364, -0.03122348,  0.03358291, ..., -1.0658293 ,
#           0.0971209 ,  0.9283074 ],
#         [ 0.06334244,  0.03192694,  0.02426939, ..., -0.09577084,
#          -0.05443887,  0.12669404],
#         [ 0.07509583, -0.03424675, -0.02759689, ..., -0.11198663,
#           0.04868139,  0.19467674],
#         ...,
#         [ 0.01279688, -0.03344777,  0.02506595, ...,  0.03743416,
#          -0.05208751,  0.04556322],
#         [-0.0141315 , -0.0491249 , -0.05260705, ...,  0.06672866,
#           0.02433945, -0.03831743],
#         [ 0.03817799, -0.01591399,  0.01752375, ...,  0.00403329,
#          -0.05103901,  0.09945498]], shape=(10000, 130), dtype=float32),
#  array([[ 0.10065881, -0.15717053, -0.02492381, ...,  0.07524348,
#          -0.00857793, -0.17256862],
#         [ 0.17020889, -0.03051712,  0.1978429 , ..., -0.11157509,
#          -0.12004051, -0.04367426],
#         [-0.07593606,  0.13666925,  0.008131  , ..., -0.07372934,
#           0.02730246,  0.14220043],
#         ...,
#         [ 0.17263675, -0.13420248,  0.1953232 , ...,  0.09168772,
#          -0.16660541, -0.10070263],
#         [-0.13233958,  0.0577667 , -0.0394911 , ..., -0.15155761,
#           0.12848824, -0.14818595],
#         [ 0.13074622, -0.07687062, -0.11388876, ..., -0.01428346,
#          -0.08234894, -0.17992577]], shape=(130, 130), dtype=float32),
#  array([[-0.11036012,  0.10742015, -0.12124827, ..., -0.27898443,
#          -0.15824005,  0.02975813],
#         [-0.04747996, -0.19725214, -0.08222421, ..., -0.06919075,
#           0.00587595, -0.01832647],
#         [ 0.01271448, -0.02686363, -0.03639217, ..., -0.0734382 ,
#           0.09108852,  0.03428235],
#         ...,
#         [ 0.08614443, -0.19242804,  0.0206588 , ..., -0.05695819,
#          -0.01029156,  0.01855934],
#         [ 0.03608336,  0.09834552,  0.0707406 , ..., -0.1338554 ,
#           0.08501253,  0.06595395],
#         [-0.00737461,  0.03979014,  0.07500683, ..., -0.08595914,
#          -0.02826692, -0.04932936]], shape=(130, 130), dtype=float32),
#  array([-2.94845998e-02, -1.94197297e-02, -6.31027622e-03,  3.73521494e-03,
#         -2.24538296e-02, -1.56000117e-03,  3.00104334e-03,  1.20651033e-02,
#         -3.03994976e-02, -2.70073414e-02,  1.39872776e-03,  2.82235700e-03,
#         -1.10301953e-02,  5.08036185e-03,  3.94785851e-02,  2.22246312e-02,
#         -9.66169522e-04,  2.58158464e-02, -2.51633395e-02, -1.54995732e-02,
#          6.68606255e-03, -2.78486665e-02, -2.74749435e-02, -4.29097004e-02,
#         -3.07603069e-02,  9.87888779e-03, -2.12469045e-02, -2.63089202e-02,
#          1.02795595e-02, -5.06723523e-02, -3.19375545e-02,  1.70771230e-03,
#         -5.03279492e-02, -1.96792111e-02, -3.31035331e-02,  3.22246924e-02,
#         -1.70452558e-02, -1.87044330e-02,  8.77154991e-03, -1.88127160e-02,
#         -2.74847224e-02,  4.58241254e-02, -7.55988806e-03,  2.33770069e-02,
#         -4.67822663e-02,  2.83360807e-03, -3.01315971e-02,  9.16652661e-03,
#          2.96613225e-03,  1.27276611e-02, -3.05789150e-02,  2.58612093e-02,
#         -1.55122057e-02, -2.94755679e-02, -2.69025993e-02, -1.88534334e-02,
#          4.42814128e-03, -1.24632567e-02,  3.83901130e-03, -1.99277904e-02,
#         -3.02735083e-02,  2.59889085e-02,  1.34224147e-02, -3.14043500e-02,
#         -7.09421409e-04,  1.08509269e-02, -6.47930149e-03, -2.39786897e-02,
#         -4.09724675e-02, -3.43610086e-02, -2.88471188e-02, -1.37073575e-02,
#          2.66973581e-03, -3.97394709e-02, -2.24945899e-02,  2.31069364e-02,
#          7.68153043e-03, -1.73246842e-02,  2.97134705e-02, -3.62057053e-02,
#         -1.69083998e-02, -2.02491060e-02,  5.68980630e-03,  3.71931195e-02,
#         -2.44706124e-02,  2.09824629e-02,  2.08065864e-02, -2.90025002e-03,
#          2.23876387e-02, -9.02860332e-03, -2.53963377e-02,  2.51162872e-02,
#         -3.22923921e-02, -4.34018224e-02, -2.06256397e-02, -8.24756362e-03,
#         -4.38902192e-02, -3.33488546e-02, -3.86178913e-03, -3.82914022e-02,
#         -1.28923776e-02, -8.44880124e-05,  5.84117370e-03, -4.22433279e-02,
#         -3.36438827e-02,  4.02246136e-03, -1.34809152e-03,  8.83009192e-03,
#         -1.48590198e-02, -4.20521125e-02,  1.60286333e-02, -4.68495302e-02,
#         -8.11239984e-03, -3.17914560e-02, -3.11665842e-03, -4.15931037e-03,
#         -5.07414108e-04, -3.75385396e-02,  2.00708187e-03, -2.59327758e-02,
#         -2.06781761e-03, -4.13563475e-02, -1.89855173e-02, -4.03666794e-02,
#         -3.03172097e-02, -1.43134501e-02, -2.71878038e-02, -2.75587905e-02,
#          1.63384546e-02, -4.06398326e-02], dtype=float32),
#  array([[ 0.06676707],
#         [ 0.10249002],
#         [-0.2216593 ],
#         [-0.0893416 ],
#         [-0.08268249],
#         [-0.26722813],
#         [ 0.13734776],
#         [ 0.11722219],
#         [-0.11432391],
#         [ 0.14821649],
#         [ 0.23839377],
#         [ 0.02896851],
#         [-0.17855902],
#         [-0.15589258],
#         [ 0.24659717],
#         [ 0.01212757],
#         [-0.09211317],
#         [-0.22457913],
#         [ 0.17389248],
#         [ 0.19598328],
#         [-0.17740978],
#         [ 0.16605976],
#         [-0.24566962],
#         [-0.05437638],
#         [-0.13482903],
#         [-0.23365802],
#         [-0.1577295 ],
#         [ 0.0479814 ],
#         [-0.06129143],
#         [ 0.063311  ],
#         [ 0.20457374],
#         [ 0.05496353],
#         [ 0.07179865],
#         [ 0.20561464],
#         [-0.17930652],
#         [-0.11852433],
#         [-0.24714161],
#         [ 0.17608392],
#         [ 0.14910994],
#         [ 0.10654829],
#         [ 0.1370043 ],
#         [-0.1373921 ],
#         [-0.21999918],
#         [-0.2291038 ],
#         [ 0.10659642],
#         [ 0.1496508 ],
#         [ 0.20044103],
#         [-0.14256358],
#         [-0.1999299 ],
#         [ 0.3035588 ],
#         [-0.02237327],
#         [-0.19082785],
#         [ 0.03203121],
#         [ 0.01197582],
#         [-0.23065929],
#         [ 0.06592719],
#         [-0.21158843],
#         [ 0.10987845],
#         [-0.11746926],
#         [ 0.12811786],
#         [ 0.14943993],
#         [ 0.11955482],
#         [-0.02571651],
#         [-0.02760296],
#         [-0.1986034 ],
#         [-0.21825214],
#         [ 0.11704756],
#         [ 0.06738301],
#         [-0.13166162],
#         [ 0.10583528],
#         [ 0.13833839],
#         [-0.04711184],
#         [-0.28971314],
#         [ 0.16655603],
#         [ 0.16492432],
#         [-0.09015527],
#         [-0.24864171],
#         [-0.04778879],
#         [-0.26454067],
#         [-0.02891204],
#         [-0.12980905],
#         [ 0.15637317],
#         [ 0.06130018],
#         [ 0.1094516 ],
#         [ 0.13162349],
#         [ 0.03132786],
#         [ 0.21056214],
#         [ 0.01001145],
#         [-0.09893744],
#         [ 0.24855144],
#         [ 0.04425338],
#         [ 0.11658682],
#         [ 0.09936401],
#         [ 0.04009563],
#         [ 0.00591682],
#         [ 0.15000679],
#         [ 0.18306777],
#         [-0.22459944],
#         [-0.11382266],
#         [-0.15212223],
#         [-0.07192127],
#         [ 0.18462904],
#         [-0.06205107],
#         [-0.14059994],
#         [-0.03153331],
#         [-0.35633844],
#         [-0.15528584],
#         [ 0.03735613],
#         [ 0.07641684],
#         [-0.09597364],
#         [ 0.15566155],
#         [-0.0791458 ],
#         [ 0.0902902 ],
#         [-0.01057894],
#         [ 0.1548261 ],
#         [ 0.00579747],
#         [-0.09293403],
#         [-0.12320543],
#         [-0.27445337],
#         [ 0.15032607],
#         [-0.07004911],
#         [ 0.1834453 ],
#         [-0.20845047],
#         [ 0.01018828],
#         [ 0.01048345],
#         [ 0.20463549],
#         [ 0.13590997],
#         [ 0.00774368],
#         [ 0.16791539],
#         [-0.0023355 ]], dtype=float32),
#  array([-0.0048205], dtype=float32)]

# %%
def decode_review(encoded_review):
    return ' '.join([reverse_word_index.get(i-3,'?') for i in encoded_review])

def preprocess_text(text):
    words = text.lower().split()
    encoded_review = [word_index.get(word,2)+3 for word in words]
    padded_review = sequence.pad_sequences([encoded_review],maxlen=500)
    return padded_review

# %%
#Prediction function

def predict_sentiment(review):
    preprocessText = preprocess_text(review)
    prediction = model.predict(preprocessText)
    sentiment = 'Positive' if prediction[0][0] >0.5 else 'Negative'
    return sentiment,prediction[0][0]

# %%
example_review = "This movie was fantastic! The acting was great and the plot was thrilling."

senti, score = predict_sentiment(example_review)

print(f'Review: {example_review}')
print(f'Sentiment: {senti}')
print(f'Score: {score}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Review: This movie was fantastic! The acting was great and the plot was thrilling.
# Sentiment: Positive
# Score: 0.558279275894165
